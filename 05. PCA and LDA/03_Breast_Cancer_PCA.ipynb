# %% [markdown]
# <!--NAVIGATION-->
#
# <a href="https://colab.research.google.com/github/bpesquet/machine-learning-katas/blob/master/classic-datasets/Breast_Cancer.ipynb"><img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open in Google Colaboratory"></a>

# %% [markdown]
# # Breast Cancer Dataset
#
# | Learning type | Activity type | Objective |
# | - | - | - |
# | Supervised | Binary classification | Predict if a tumor is benign or malignant |

# %% [markdown]
# ## About the dataset
#
# The [Breast Cancer][1] dataset is used for multivariate binary classification. There are 569 total samples with 30 features each. Features were computed from a digitized image of a fine needle aspirate of a breast mass. They describe characteristics of the cell nuclei present in the image.
#
# ![](images/breast-cancer-logo.jpg)
#
# [1]: https://archive.ics.uci.edu/ml/datasets/Breast+Cancer+Wisconsin+(Diagnostic)

# %% [markdown]
# ## Package setup

# %%
#DO THE NECESSARY IMPORTS

import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from sklearn.datasets import load_breast_cancer
from sklearn import model_selection
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing
from sklearn.model_selection import KFold, LeaveOneOut, cross_val_score

# Set random seed
np.random.seed(0)
# Display plots inline, change default figure size and change plot resolution to retina
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
# Set Seaborn aesthetic parameters to defaults
sns.set()

# %% [markdown]
# ## Step 1: Loading the data
# **EXERCISE: In a similar was as you did with iris and wine ;).**

# %%
dataset = load_breast_cancer()

# %%
dataset.keys()
# Out:
# dict_keys(['data', 'target', 'frame', 'target_names', 'DESCR', 'feature_names', 'filename', 'data_module'])

# %%
# Put data in a pandas DataFrame
df_breast = pd.DataFrame(dataset.data, columns=dataset.feature_names)
df_breast.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# 0                 0.07871  ...         25.38          17.33           184.60
# 1                 0.05667  ...         24.99          23.41           158.80
# 2                 0.05999  ...         23.57          25.53           152.50
# 3                 0.09744  ...         14.91          26.50            98.87
# 4                 0.05883  ...         22.54          16.67           152.20
#
#    worst area  worst smoothness  worst compactness  worst concavity  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    worst concave points  worst symmetry  worst fractal dimension
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 30 columns]

# %%
# Add target and class to DataFrame
df_breast['target'] = dataset.target
df_breast["class"] = dataset.target_names[dataset.target]
df_breast.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst perimeter  worst area  worst smoothness  \
# 0                 0.07871  ...           184.60      2019.0            0.1622
# 1                 0.05667  ...           158.80      1956.0            0.1238
# 2                 0.05999  ...           152.50      1709.0            0.1444
# 3                 0.09744  ...            98.87       567.7            0.2098
# 4                 0.05883  ...           152.20      1575.0            0.1374
#
#    worst compactness  worst concavity  worst concave points  worst symmetry  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.1866           0.2416                0.1860          0.2750
# 2             0.4245           0.4504                0.2430          0.3613
# 3             0.8663           0.6869                0.2575          0.6638
# 4             0.2050           0.4000                0.1625          0.2364
#
#    worst fractal dimension  target      class
# 0                  0.11890       0  malignant
# 1                  0.08902       0  malignant
# 2                  0.08758       0  malignant
# 3                  0.17300       0  malignant
# 4                  0.07678       0  malignant
#
# [5 rows x 32 columns]

# %% [markdown]
# Since the original labels are in 0,1 format, we could change the labels to benign and malignant using .replace function. Using inplace=True will modify the dataframe breast_dataset.
# **Optional**

# %%
df_breast['target'].replace(0, 'Malignant',inplace=True)
df_breast['target'].replace(1, 'Benign',inplace=True)
# if we do this we should also drop the class
df=df_breast.drop("class")
df_breast.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\Lenovo\OneDrive\Documents\Strive repos\strive_practice\05. PCA and LDA\03_Breast_Cancer_PCA.ipynb Cell 13' in <cell line: 4>()
#       <a href='vscode-notebook-cell:/c%3A/Users/Lenovo/OneDrive/Documents/Strive%20repos/strive_practice/05.%20PCA%20and%20LDA/03_Breast_Cancer_PCA.ipynb#ch0000010?line=1'>2</a> df_breast['target'].replace(1, 'Benign',inplace=True)
#       <a href='vscode-notebook-cell:/c%3A/Users/Lenovo/OneDrive/Documents/Strive%20repos/strive_practice/05.%20PCA%20and%20LDA/03_Breast_Cancer_PCA.ipynb#ch0000010?line=2'>3</a> # if we do this we should also drop the class
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Lenovo/OneDrive/Documents/Strive%20repos/strive_practice/05.%20PCA%20and%20LDA/03_Breast_Cancer_PCA.ipynb#ch0000010?line=3'>4</a> df=df_breast.drop("class")
#       <a href='vscode-notebook-cell:/c%3A/Users/Lenovo/OneDrive/Documents/Strive%20repos/strive_practice/05.%20PCA%20and%20LDA/03_Breast_Cancer_PCA.ipynb#ch0000010?line=4'>5</a> df_breast.head()
#
# File ~\anaconda3\envs\strive2\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///c%3A/Users/Lenovo/anaconda3/envs/strive2/lib/site-packages/pandas/util/_decorators.py?line=304'>305</a> if len(args) > num_allow_args:
#     <a href='file:///c%3A/Users/Lenovo/anaconda3/envs/strive2/lib/site-packages/pandas/util/_decorators.py?line=305'>306</a>     warnings.warn(
#     <a href='file:///c%3A/Users/Lenovo/anaconda3/envs/strive2/lib/site-packages/pandas/util/_decorators.py?line=306'>307</a>         msg.format(arguments=arguments),
#     <a href='file:///c%3A/Users/Lenovo/anaconda3/envs/strive2/lib/site-packages/pandas/util/_decorators.py?line=307'>308</a>         FutureWarning,
#     <a href='file:///c%3A/Users/Lenovo/anaconda3/envs/strive2/lib/site-packages/pandas/util/_decorators.py?line=308'>309</a>         stacklevel=stacklevel,
#     <a href='file:///c%3A/Users/Lenovo/anaconda3/envs/strive2/lib/site-packages/pandas/util/_decorators.py?line=309'>310</a>     )
# --> <a href='file:///c%3A/Users/Lenovo/anaconda3/envs/strive2/lib/site-packages/pandas/util/_decorators.py?line=310'>311</a> return func(*args, **kwargs)
#
# File ~\anaconda3\envs\strive2\lib\site-packages\pandas\core\frame.py:4948, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    <a href='file:///c%3A/Users/Lenovo/anaconda3/envs/strive2/lib/site-packages/pandas/core/frame.py?line=4799'>4800</a> @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    <a href='file:///c%3A/Users/Lenovo/anaconda3/envs/strive2/lib/site-packages/pandas/core/frame.py?line=4800'>4801</a> def drop(
#    <a href='file:///c%3A/Users/Lenovo/anaconda3/envs/strive2/lib/site-packages/pandas/core/frame.py?line=4801'>4802</a>     self,
#    (...)
#    <a href='file:///c%3A/Users/Lenovo/anaconda3/envs/strive2/lib/site-packages/pandas/core/frame.py?line=4808'>4809</a>     errors: str = "raise",
#    <a href='file:///c%3A/Users/Lenovo/anaconda3/envs/strive2/lib/site-packages/pandas/core/frame.py?line=4809'>4810</a> ):
#    <a href='file:///c%3A/Users/Lenovo/anaconda3/envs/strive2/lib/site-packages/pandas/core/frame.py?line=4810'>4811</a>     """
#    <a href='file:///c%3A/Users/Lenovo/anaconda3/envs/strive2/lib/site-packages/pandas/core/frame.py?line=4811'>4812</a>     Drop specified labels from rows or columns.
#    <a href='file:///c%3A/Users/Lenovo/anaconda3/envs/strive2/lib/site-packages/pandas/core/frame.py?line=4812'>4813</a>
#    (...)
#    <a href='file:///c%3A/Users/Lenovo/anaconda3/envs/strive2/lib/site-packages/pandas/core/frame.py?line=4945'>4946</a>             weight  1.0     0.8
#    <a href='file:///c%3A/Users/Lenovo/anaconda3/envs/strive2/lib/site-packages/pandas/core/frame.py?line=4946'>4947</a>     """
# -> <a href='file:///c%3A/Users/Lenovo/anaconda3/envs/strive2/lib/site-packages/pandas/core/frame.py?line=4947'>4948</a>     return super().drop(
#    <a href='file:///c%3A/Users/Lenovo/anaconda3/envs/strive2/lib/site-packages/pandas/core/frame.py?line=4948'>4949</a>         labels=labels,
#    <a href='file:///c%3A/Users/Lenovo/anaconda3/envs/strive2/lib/site-packages/pandas/core/frame.py?line=4949'>4950</a>         axis=axis,
#    <a href='file:///c%3A/Users/Lenovo/anaconda3/envs/strive2/lib/site-packages/pandas/core/frame.py?line=4950'>4951</a>         index=index,
#    <a href='file:///c%3A/Users/Lenovo/anaconda3/envs/strive2/lib/site-packages/pandas/core/frame.py?line=4951'>4952</a>         columns=columns,
#    <a href='file:///c%3A/Users/Lenovo/anaconda3/envs/strive2/lib/site-packages/pandas/core/frame.py?line=4952'>4953</a>         level=level,
#    <a href='file:///c%3A/Users/Lenovo/anaconda3/envs/strive2/lib/site-packages/pandas/core/frame.py?line=4953'>4954</a>         inplace=inplace,
#    <a href='file:///c%3A/Users/Lenovo/anaconda3/envs/strive2/lib/site-packages/pandas/core/frame.py?line=4954'>4955</a>         errors=errors,
#    <a href='file:///c%3A/Users/Lenovo/anaconda3/envs/strive2/lib/site-packages/pandas/core/frame.py?line=4955'>4956</a>     )
#
# File ~\anaconda3\envs\strive2\lib\site-packages\pandas\core\generic.py:4279, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    <a href='file:///c%3A/Users/Lenovo/anaconda3/envs/strive2/lib/site-packages/pandas/core/generic.py?line=4276'>4277</a> for axis, labels in axes.items():
#    <a href='file:///c%3A/Users/Lenovo/anaconda3/envs/strive2/lib/site-packages/pandas/core/generic.py?line=4277'>4278</a>     if labels is not None:
# -> <a href='file:///c%3A/Users/Lenovo/anaconda3/envs/strive2/lib/site-packages/pandas/core/generic.py?line=4278'>4279</a>         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    <a href='file:///c%3A/Users/Lenovo/anaconda3/envs/strive2/lib/site-packages/pandas/core/generic.py?line=4280'>4281</a> if inplace:
#    <a href='file:///c%3A/Users/Lenovo/anaconda3/envs/strive2/lib/site-packages/pandas/core/generic.py?line=4281'>4282</a>     self._update_inplace(obj)
#
# File ~\anaconda3\envs\strive2\lib\site-packages\pandas\core\generic.py:4323, in NDFrame._drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    <a href='file:///c%3A/Users/Lenovo/anaconda3/envs/strive2/lib/site-packages/pandas/core/generic.py?line=4320'>4321</a>         new_axis = axis.drop(labels, level=level, errors=errors)
#    <a href='file:///c%3A/Users/Lenovo/anaconda3/envs/strive2/lib/site-packages/pandas/core/generic.py?line=4321'>4322</a>     else:
# -> <a href='file:///c%3A/Users/Lenovo/anaconda3/envs/strive2/lib/site-packages/pandas/core/generic.py?line=4322'>4323</a>         new_axis = axis.drop(labels, errors=errors)
#    <a href='file:///c%3A/Users/Lenovo/anaconda3/envs/strive2/lib/site-packages/pandas/core/generic.py?line=4323'>4324</a>     indexer = axis.get_indexer(new_axis)
#    <a href='file:///c%3A/Users/Lenovo/anaconda3/envs/strive2/lib/site-packages/pandas/core/generic.py?line=4325'>4326</a> # Case for non-unique axis
#    <a href='file:///c%3A/Users/Lenovo/anaconda3/envs/strive2/lib/site-packages/pandas/core/generic.py?line=4326'>4327</a> else:
#
# File ~\anaconda3\envs\strive2\lib\site-packages\pandas\core\indexes\base.py:6644, in Index.drop(self, labels, errors)
#    <a href='file:///c%3A/Users/Lenovo/anaconda3/envs/strive2/lib/site-packages/pandas/core/indexes/base.py?line=6641'>6642</a> if mask.any():
#    <a href='file:///c%3A/Users/Lenovo/anaconda3/envs/strive2/lib/site-packages/pandas/core/indexes/base.py?line=6642'>6643</a>     if errors != "ignore":
# -> <a href='file:///c%3A/Users/Lenovo/anaconda3/envs/strive2/lib/site-packages/pandas/core/indexes/base.py?line=6643'>6644</a>         raise KeyError(f"{list(labels[mask])} not found in axis")
#    <a href='file:///c%3A/Users/Lenovo/anaconda3/envs/strive2/lib/site-packages/pandas/core/indexes/base.py?line=6644'>6645</a>     indexer = indexer[~mask]
#    <a href='file:///c%3A/Users/Lenovo/anaconda3/envs/strive2/lib/site-packages/pandas/core/indexes/base.py?line=6645'>6646</a> return self.delete(indexer)
#
# KeyError: "['class'] not found in axis"

# %% [markdown]
# ## Visualizing the Breast Cancer data

# %% [markdown]
# ### Select your X and y's

# %%
# YOUR CODE HERE
X = df_breast.drop(['target', 'class'], axis=1)
y = df_breast['target']

# %% [markdown]
# ### Step 2: Normalize the data in X

# %%
#do the necessary imports (you can also do them all above)
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_scaled
# Out:
# array([[ 1.09706398, -2.07333501,  1.26993369, ...,  2.29607613,
#          2.75062224,  1.93701461],
#        [ 1.82982061, -0.35363241,  1.68595471, ...,  1.0870843 ,
#         -0.24388967,  0.28118999],
#        [ 1.57988811,  0.45618695,  1.56650313, ...,  1.95500035,
#          1.152255  ,  0.20139121],
#        ...,
#        [ 0.70228425,  2.0455738 ,  0.67267578, ...,  0.41406869,
#         -1.10454895, -0.31840916],
#        [ 1.83834103,  2.33645719,  1.98252415, ...,  2.28998549,
#          1.91908301,  2.21963528],
#        [-1.80840125,  1.22179204, -1.81438851, ..., -1.74506282,
#         -0.04813821, -0.75120669]])

# %% [markdown]
# ### Optional
#
# Convert this to a pandas dataframe again in order to visualize it.

# %%
df_x = pd.DataFrame(X_scaled)
df_x
# Out:
#            0         1         2         3         4         5         6   \
# 0    1.097064 -2.073335  1.269934  0.984375  1.568466  3.283515  2.652874
# 1    1.829821 -0.353632  1.685955  1.908708 -0.826962 -0.487072 -0.023846
# 2    1.579888  0.456187  1.566503  1.558884  0.942210  1.052926  1.363478
# 3   -0.768909  0.253732 -0.592687 -0.764464  3.283553  3.402909  1.915897
# 4    1.750297 -1.151816  1.776573  1.826229  0.280372  0.539340  1.371011
# ..        ...       ...       ...       ...       ...       ...       ...
# 564  2.110995  0.721473  2.060786  2.343856  1.041842  0.219060  1.947285
# 565  1.704854  2.085134  1.615931  1.723842  0.102458 -0.017833  0.693043
# 566  0.702284  2.045574  0.672676  0.577953 -0.840484 -0.038680  0.046588
# 567  1.838341  2.336457  1.982524  1.735218  1.525767  3.272144  3.296944
# 568 -1.808401  1.221792 -1.814389 -1.347789 -3.112085 -1.150752 -1.114873
#
#            7         8         9   ...        20        21        22  \
# 0    2.532475  2.217515  2.255747  ...  1.886690 -1.359293  2.303601
# 1    0.548144  0.001392 -0.868652  ...  1.805927 -0.369203  1.535126
# 2    2.037231  0.939685 -0.398008  ...  1.511870 -0.023974  1.347475
# 3    1.451707  2.867383  4.910919  ... -0.281464  0.133984 -0.249939
# 4    1.428493 -0.009560 -0.562450  ...  1.298575 -1.466770  1.338539
# ..        ...       ...       ...  ...       ...       ...       ...
# 564  2.320965 -0.312589 -0.931027  ...  1.901185  0.117700  1.752563
# 565  1.263669 -0.217664 -1.058611  ...  1.536720  2.047399  1.421940
# 566  0.105777 -0.809117 -0.895587  ...  0.561361  1.374854  0.579001
# 567  2.658866  2.137194  1.043695  ...  1.961239  2.237926  2.303601
# 568 -1.261820 -0.820070 -0.561032  ... -1.410893  0.764190 -1.432735
#
#            23        24        25        26        27        28        29
# 0    2.001237  1.307686  2.616665  2.109526  2.296076  2.750622  1.937015
# 1    1.890489 -0.375612 -0.430444 -0.146749  1.087084 -0.243890  0.281190
# 2    1.456285  0.527407  1.082932  0.854974  1.955000  1.152255  0.201391
# 3   -0.550021  3.394275  3.893397  1.989588  2.175786  6.046041  4.935010
# 4    1.220724  0.220556 -0.313395  0.613179  0.729259 -0.868353 -0.397100
# ..        ...       ...       ...       ...       ...       ...       ...
# 564  2.015301  0.378365 -0.273318  0.664512  1.629151 -1.360158 -0.709091
# 565  1.494959 -0.691230 -0.394820  0.236573  0.733827 -0.531855 -0.973978
# 566  0.427906 -0.809587  0.350735  0.326767  0.414069 -1.104549 -0.318409
# 567  1.653171  1.430427  3.904848  3.197605  2.289985  1.919083  2.219635
# 568 -1.075813 -1.859019 -1.207552 -1.305831 -1.745063 -0.048138 -0.751207
#
# [569 rows x 30 columns]

# %% [markdown]
# ### Short exercise
# Let's check whether the normalized data has a mean of zero and a standard deviation of one. **Those are indicators of proper normalization**

# %%
print(np.mean(X_scaled))
np.std(X_scaled)
# Out:
# -6.118909323768877e-16
# 1.0

# %% [markdown]
# ## Apply the PCA Method

# %%
#do the necessary imports
from sklearn.decomposition import PCA
pca = PCA(n_components=2)

# %%
X_pca = pca.fit_transform(X_scaled)

# %% [markdown]
# Next, let's create a **new DataFrame** that will have the principal component values for all the samples.

# %%
df_principal_breast = pd.DataFrame(X_pca, columns=('principal component 1', 'principal component 2'))
df_principal_breast
# Out:
#      principal component 1  principal component 2
# 0                 9.192837               1.948583
# 1                 2.387802              -3.768172
# 2                 5.733896              -1.075174
# 3                 7.122953              10.275589
# 4                 3.935302              -1.948072
# ..                     ...                    ...
# 564               6.439315              -3.576817
# 565               3.793382              -3.584048
# 566               1.256179              -1.902297
# 567              10.374794               1.672010
# 568              -5.475243              -0.670637
#
# [569 rows x 2 columns]

# %% [markdown]
# Once you have the principal components, you can find the **explained_variance_ratio**. It will provide you with the amount of information or variance each principal component holds after projecting the data to a lower dimensional subspace.

# %%
print('Explained variation per principal component: {}'.format(pca.explained_variance_ratio_))
# Out:
# Explained variation per principal component: [0.44272026 0.18971182]

# %% [markdown]
# From the above output, you can observe that the principal component 1 holds **44.2%** of the information while the principal component 2 holds only **19%** of the information. Also, the other point to note is that while projecting thirty-dimensional data to a two-dimensional data, 36.8% information was lost.

# %% [markdown]
# ## Plotting the visualization

# %%
plt.figure()
plt.figure(figsize=(10,10))
plt.xticks(fontsize=12)
plt.yticks(fontsize=14)
plt.xlabel('Principal Component - 1',fontsize=20)
plt.ylabel('Principal Component - 2',fontsize=20)
plt.title("Principal Component Analysis of Breast Cancer Dataset",fontsize=20)
targets = [0, 1]
colors = ['r', 'g']
for target, color in zip(targets,colors):
    indicesToKeep = df_breast['target'] == target
    plt.scatter(df_principal_breast.loc[indicesToKeep, 'principal component 1']
               , df_principal_breast.loc[indicesToKeep, 'principal component 2'], c = color, s = 50)

plt.legend(targets,prop={'size': 15})

# %% [markdown]
# ### Additional Challenge: Can you fix the labels in the plot so they are the original classes?
# Benign and Malign instead of 1 and 0
